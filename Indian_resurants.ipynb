# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\sanja\\Downloads\\restaurants.csv")
df
# Out:
#                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Location    0
# Locality    0
# City        0
# Cuisine     0
# Rating      0
# Votes       0
# Cost        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6593 entries, 0 to 6592
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6593 non-null   object
#  1   Location  6593 non-null   object
#  2   Locality  6593 non-null   object
#  3   City      6593 non-null   object
#  4   Cuisine   6593 non-null   object
#  5   Rating    6593 non-null   float64
#  6   Votes     6593 non-null   int64
#  7   Cost      6593 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 412.2+ KB

# %%
Top_10_rsturants = df.Name.value_counts().sort_values(ascending = False).head(10)
Top_10_rsturants = Top_10_rsturants.reset_index()
Top_10_rsturants.rename(columns={'index':"resturant","Name":'frequency'},inplace=True)
Top_10_rsturants
# Out:
#                 resturant  frequency
# 0               Wow! Momo         67
# 1            Kanti Sweets         65
# 2         Barbeque Nation         48
# 3               Taco Bell         44
# 4  Dindigul Thalappakatti         33
# 5         Mad Over Donuts         29
# 6           Frozen Bottle         28
# 7                  Subway         27
# 8      California Burrito         26
# 9           Beijing Bites         25

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='resturant',y='frequency',data=Top_10_rsturants)
# Out:
# <Axes: xlabel='resturant', ylabel='frequency'>

# %%
top_resturant_rating = df.groupby('Name')['Rating'].sum().sort_values(ascending=False).head(10)
top_resturant_rating = top_resturant_rating.reset_index()
top_resturant_rating
# Out:
#                      Name  Rating
# 0            Kanti Sweets   267.3
# 1               Wow! Momo   247.3
# 2         Barbeque Nation   211.6
# 3               Taco Bell   183.2
# 4  Dindigul Thalappakatti   135.0
# 5         Mad Over Donuts   128.4
# 6           Frozen Bottle   115.2
# 7                  Subway   112.9
# 8      California Burrito   112.7
# 9           Beijing Bites   103.6

# %%
plt.figure(figsize=(12,5))

ax = sns.barplot(x="Name",y="Rating",data=top_resturant_rating)

plt.title("Top Resturant By Rating")
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Locality', 'City', 'Cuisine', 'Rating', 'Votes',
#        'Cost'],
#       dtype='object')

# %%
df[["Cuisine","Cost"]].sort_values(by = "Cost",ascending=False).head(10)
# Out:
#                                                 Cuisine  Cost
# 1672                           European,  Modern Indian  8000
# 632                              North Indian,  Mughlai  6000
# 199                      Italian,  Continental,  French  5000
# 944        North Indian,  Continental,  Italian,  Asian  5000
# 119                                   Italian,  Spanish  5000
# 1267                                            Italian  5000
# 467   Multi-Cuisine,  North Indian,  Italian,  Chine...  5000
# 1223                        North Indian,  South Indian  5000
# 3614               North Indian,  Chinese,  Continental  5000
# 6295                 North Indian,  Fast Food,  Arabian  5000
