# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
files = [file for file in os.listdir("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\domestic_visitors") ]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\domestic_visitors\\"+file)
    all_months_data = pd.concat([all_months_data,df])

all_months_data.to_csv("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\domestic_visitors.csv",index=False)

# %%
files = [file for file in os.listdir("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\foreign_visitors") ]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\foreign_visitors\\"+file)
    all_months_data = pd.concat([all_months_data,df])

all_months_data.to_csv("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\foreign_visitors_visitors.csv",index=False)

# %%
dv = pd.read_csv("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\domestic_visitors.csv")
dv
# Out:
#              district       date      month  year visitors
# 0            Adilabad   1/1/2016    January  2016   792136
# 1            Adilabad   1/2/2016   February  2016   937820
# 2            Adilabad   1/3/2016      March  2016   582946
# 3            Adilabad   1/4/2016      April  2016   341948
# 4            Adilabad   1/5/2016        May  2016   252887
# ...               ...        ...        ...   ...      ...
# 1507  Yadadri Bhongir   1/8/2019     August  2019   389010
# 1508  Yadadri Bhongir   1/9/2019  September  2019   366862
# 1509  Yadadri Bhongir  1/10/2019    October  2019   381860
# 1510  Yadadri Bhongir  1/11/2019   November  2019   365990
# 1511  Yadadri Bhongir  1/12/2019   December  2019   477635
#
# [1512 rows x 5 columns]

# %%
fv = pd.read_csv("C:\\Users\\sanja\\Downloads\\C5 Input for participants\\foreign_visitors_visitors.csv")

# %%
dv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  1512 non-null   object
#  1   date      1512 non-null   object
#  2   month     1512 non-null   object
#  3   year      1512 non-null   int64
#  4   visitors  1482 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 59.2+ KB

# %%
dv.dropna(inplace=True)

# %%
dv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1482 entries, 0 to 1511
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  1482 non-null   object
#  1   date      1482 non-null   object
#  2   month     1482 non-null   object
#  3   year      1482 non-null   int64
#  4   visitors  1482 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 69.5+ KB

# %%
print("The zero length string without spaces is empty ? : ", end=" ")
if(len(dv['visitors']) == 0):
    print("Yes")
else:
    print("No")
# Out:
# The zero length string without spaces is empty ? :  No

# %%
dv['visitors'] = dv['visitors'].replace("",0)

# %%
dv.head(20)
# Out:
#                  district       date      month  year visitors
# 0                Adilabad   1/1/2016    January  2016   792136
# 1                Adilabad   1/2/2016   February  2016   937820
# 2                Adilabad   1/3/2016      March  2016   582946
# 3                Adilabad   1/4/2016      April  2016   341948
# 4                Adilabad   1/5/2016        May  2016   252887
# 5                Adilabad   1/6/2016       June  2016   368237
# 6                Adilabad   1/7/2016       July  2016   447562
# 7                Adilabad   1/8/2016     August  2016   614285
# 8                Adilabad   1/9/2016  September  2016   491279
# 9                Adilabad  1/10/2016    October  2016    94184
# 10               Adilabad  1/11/2016   November  2016    99148
# 11               Adilabad  1/12/2016   December  2016    53125
# 12  Bhadradri Kothagudem    1/1/2016    January  2016        0
# 13  Bhadradri Kothagudem    1/2/2016   February  2016        0
# ...

# %%
dv['visitors'] = dv['visitors'].astype(float)

# %%
top_10_dist = dv.groupby('district')['visitors'].sum().reset_index().sort_values(by="visitors",ascending=False).head(10)

# %%
top_10_dist
# Out:
#                     district    visitors
# 2                  Hyderabad  83900960.0
# 23         Rajanna Sircilla   41763276.0
# 31          Warangal (Urban)  30726603.0
# 32           Yadadri Bhongir  26893080.0
# 1      Bhadradri Kothagudem   21600962.0
# 14                    Medak   20542639.0
# 5   Jayashankar Bhoopalpally  19632865.0
# 12               Mahbubnagar  17180118.0
# 20                    Nirmal  13315796.0
# 3                   Jagtial   11303514.0

# %%
plt.figure(figsize=(13,5))
sns.barplot(x="district",y="visitors",data=top_10_dist)
# Out:
# <Axes: xlabel='district', ylabel='visitors'>

# %%
dv.g
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 dv.groupby(['month'])['district']['Hyderabad']
#
# File c:\Users\sanja\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:233, in SelectionMixin.__getitem__(self, key)
#     231 def __getitem__(self, key):
#     232     if self._selection is not None:
# --> 233         raise IndexError(f"Column(s) {self._selection} already selected")
#     235     if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#     236         if len(self.obj.columns.intersection(key)) != len(set(key)):
#
# IndexError: Column(s) district already selected
