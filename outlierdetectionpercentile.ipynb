# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\sanja\\Downloads\\100-days-of-machine-learning-main\\day44-outlier-detection-using-percentiles\\weight-height.csv")

# %%
df.sample(5)
# Out:
#       Gender     Height      Weight
# 7739  Female  61.576625  109.076317
# 130     Male  67.492193  191.699605
# 2784    Male  68.955335  193.828445
# 1560    Male  69.944986  182.346218
# 9239  Female  65.899387  153.530540

# %%
df.shape
# Out:
# (10000, 3)

# %%
sns.histplot(df['Height'],kde=True, stat='probability')
# Out:
# <Axes: xlabel='Height', ylabel='Probability'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: >

# %%
upper_limit = df['Height'].quantile(0.99)
lower_limit = df['Height'].quantile(0.01)
upper_limit, lower_limit
# Out:
# (74.7857900583366, 58.13441158671655)

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13)]

# %%
sns.boxplot(new_df['Height'])
# Out:
# <Axes: >
