# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\sanja\\Downloads\\scrap_phone.csv")
df.head()
# Out:
#                   model    price  rating  \
# 0  Motorola Edge 40 Neo  ₹22,999      84
# 1              Vivo V29  ₹31,400      85
# 2    Xiaomi Redmi 12 5G  ₹11,999      75
# 3  OnePlus Nord CE 3 5G  ₹24,999      84
# 4  Motorola Moto G54 5G  ₹14,999      84
#
#                                                  sim  \
# 0            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                       ram  \
# 0     Dimensity 7030, Octa Core, 2.5 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1    Snapdragon 778G, Octa Core, 2.4 GHz Processor  8 GB RAM, 128 GB inbuilt
# 2  Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor  4 GB RAM, 128 GB inbuilt
# 3   Snapdragon  782G, Octa Core, 2.7 GHz Processor  8 GB RAM, 128 GB inbuilt
# 4     Dimensity 7020, Octa Core, 2.2 GHz Processor  8 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 68W Fast Charging
# 1  4600 mAh Battery with 80W Fast Charging
# 2  5000 mAh Battery with 18W Fast Charging
# 3  5000 mAh Battery with 80W Fast Charging
# 4  6000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.55 inches, 1080 x 2400 px, 144 Hz Display wi...
# 1  6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 2  6.79 inches, 1080 x 2460 px, 90 Hz Display wit...
# 3  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 4  6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
#
#                                               camera  \
# 0       50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 1  50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 2         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4        50 MP + 8 MP Dual Rear & 16 MP Front Camera
#
#                               card           os
# 0        Memory Card Not Supported  Android v13
# 1                      Android v13  No FM Radio
# 2  Memory Card (Hybrid), upto 1 TB  Android v13
# 3  Memory Card (Hybrid), upto 1 TB  Android v13
# 4  Memory Card (Hybrid), upto 1 TB  Android v13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     1020 non-null   int64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1018 non-null   object
#  9   card       991 non-null    object
#  10  os         958 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = df.copy()

# %%
df1['price'] = df1['price'].str.replace('₹','').str.replace(',', '').astype(int)

# %%
df1
# Out:
#                      model  price  rating  \
# 0     Motorola Edge 40 Neo  22999      84
# 1                 Vivo V29  31400      85
# 2       Xiaomi Redmi 12 5G  11999      75
# 3     OnePlus Nord CE 3 5G  24999      84
# 4     Motorola Moto G54 5G  14999      84
# ...                    ...    ...     ...
# 1015          iAir D40 Pro    934      14
# 1016   Snexian Bold Slim 2   1149      15
# 1017        GFive Rose 999   1099      12
# 1018         Lvix L1 ICE 2    649      10
# 1019          GFive A2 New    699      13
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                                           Dual Sim
# 1016                                         Triple Sim
# 1017                                  770 kHz Processor
# 1018                                           Dual Sim
# 1019                                           Dual Sim
#
#                                             processor  \
# 0        Dimensity 7030, Octa Core, 2.5 GHz Processor
# 1       Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 2     Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# 3      Snapdragon  782G, Octa Core, 2.7 GHz Processor
# 4        Dimensity 7020, Octa Core, 2.2 GHz Processor
# ...                                               ...
# 1015                     Dual Core, 1.4 GHz Processor
# 1016                                          No Wifi
# 1017                         32 MB RAM, 16 MB inbuilt
# 1018                               1.77 MHz Processor
# 1019                                1.2 MHz Processor
#
#                            ram                                  battery  \
# 0     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68W Fast Charging
# 1     8 GB RAM, 128 GB inbuilt  4600 mAh Battery with 80W Fast Charging
# 2     4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 3     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 80W Fast Charging
# 4     8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 33W Fast Charging
# ...                        ...                                      ...
# 1015  32 MB RAM, 32 MB inbuilt                         2500 mAh Battery
# 1016          3000 mAh Battery         2.4 inches, 240 x 320 px Display
# 1017          3000 mAh Battery         2.4 inches, 128 x 160 px Display
# 1018  16 MB RAM, 32 MB inbuilt                         1000 mAh Battery
# 1019  32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
#
#                                                 display  \
# 0     6.55 inches, 1080 x 2400 px, 144 Hz Display wi...
# 1     6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 2     6.79 inches, 1080 x 2460 px, 90 Hz Display wit...
# 3     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 4     6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# ...                                                 ...
# 1015                  1.44 inches, 128 x 160 px Display
# 1016                                     No Rear Camera
# 1017                                 0.3 MP Rear Camera
# 1018                  1.77 inches, 176 x 220 px Display
# 1019                   1.8 inches, 320 x 480 px Display
#
#                                                  camera  \
# 0          50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 1     50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 2            50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# ...                                                 ...
# 1015                                 0.8 MP Rear Camera
# 1016                  Memory Card Supported, upto 16 GB
# 1017                              Memory Card Supported
# 1018                                 0.3 MP Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                    card           os
# 0             Memory Card Not Supported  Android v13
# 1                           Android v13  No FM Radio
# 2       Memory Card (Hybrid), upto 1 TB  Android v13
# 3       Memory Card (Hybrid), upto 1 TB  Android v13
# 4       Memory Card (Hybrid), upto 1 TB  Android v13
# ...                                 ...          ...
# 1015                          Bluetooth          NaN
# 1016                          Bluetooth          NaN
# 1017                                NaN          NaN
# 1018              Memory Card Supported        v1.77
# 1019  Memory Card Supported, upto 16 GB    Bluetooth
#
# [1016 rows x 11 columns]

# %%
df1 = df1[df1['price'] >=3400]

# %%
df1
# Out:
#                      model  price  rating  \
# 0     Motorola Edge 40 Neo  22999      84
# 1                 Vivo V29  31400      85
# 2       Xiaomi Redmi 12 5G  11999      75
# 3     OnePlus Nord CE 3 5G  24999      84
# 4     Motorola Moto G54 5G  14999      84
# ..                     ...    ...     ...
# 971               Vivo Y66  15050      53
# 972  Motorola Moto E4 Plus   5499      55
# 973      BlackBerry DTEK50  13499      57
# 974            Lyf Water 1   4290      50
# 976         Vivo Y15s 2015   7070      44
#
#                                                    sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ..                                                 ...
# 971                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 972                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 973                          Single Sim, 3G, 4G, Wi-Fi
# 974                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 976                                Dual Sim, 3G, Wi-Fi
#
#                                             processor  \
# 0        Dimensity 7030, Octa Core, 2.5 GHz Processor
# 1       Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 2     Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor
# 3      Snapdragon  782G, Octa Core, 2.7 GHz Processor
# 4        Dimensity 7020, Octa Core, 2.2 GHz Processor
# ..                                                ...
# 971  Snapdragon MSM8937, Octa Core, 1.4 GHz Processor
# 972        Helio MT6737, Quad Core, 1.3 GHz Processor
# 973      Snapdragon 617, Octa Core, 1.5 GHz Processor
# 974  Snapdragon MSM8939, Octa Core, 1.5 GHz Processor
# 976        Helio MT6580, Quad Core, 1.3 GHz Processor
#
#                           ram                                  battery  \
# 0    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68W Fast Charging
# 1    8 GB RAM, 128 GB inbuilt  4600 mAh Battery with 80W Fast Charging
# 2    4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 3    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 80W Fast Charging
# 4    8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 33W Fast Charging
# ..                        ...                                      ...
# 971   3 GB RAM, 32 GB inbuilt                         3000 mAh Battery
# 972   3 GB RAM, 32 GB inbuilt                         5000 mAh Battery
# 973   3 GB RAM, 16 GB inbuilt                         2610 mAh Battery
# 974   2 GB RAM, 16 GB inbuilt                         2600 mAh Battery
# 976    1 GB RAM, 8 GB inbuilt                         1900 mAh Battery
#
#                                                display  \
# 0    6.55 inches, 1080 x 2400 px, 144 Hz Display wi...
# 1    6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# 2    6.79 inches, 1080 x 2460 px, 90 Hz Display wit...
# 3    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 4    6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# ..                                                 ...
# 971                  5.5 inches, 720 x 1280 px Display
# 972                  5.5 inches, 720 x 1280 px Display
# 973                 5.2 inches, 1080 x 1920 px Display
# 974                   5 inches, 1080 x 1920 px Display
# 976                   4.5 inches, 480 x 854 px Display
#
#                                                 camera  \
# 0         50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 1    50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 2           50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 3    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4          50 MP + 8 MP Dual Rear & 16 MP Front Camera
# ..                                                 ...
# 971                    13 MP Rear & 16 MP Front Camera
# 972                     13 MP Rear & 5 MP Front Camera
# 973                     13 MP Rear & 8 MP Front Camera
# 974                     13 MP Rear & 5 MP Front Camera
# 976                      5 MP Rear & 2 MP Front Camera
#
#                                    card                          os
# 0             Memory Card Not Supported                 Android v13
# 1                           Android v13                 No FM Radio
# 2       Memory Card (Hybrid), upto 1 TB                 Android v13
# 3       Memory Card (Hybrid), upto 1 TB                 Android v13
# 4       Memory Card (Hybrid), upto 1 TB                 Android v13
# ..                                  ...                         ...
# 971  Memory Card Supported, upto 128 GB  Android v6.0 (Marshmallow)
# 972  Memory Card Supported, upto 128 GB     Android v7.1.1 (Nougat)
# 973               Memory Card Supported  Android v6.0 (Marshmallow)
# 974   Memory Card Supported, upto 32 GB     Android v5.1 (Lollipop)
# 976  Memory Card Supported, upto 128 GB     Android v5.1 (Lollipop)
#
# [869 rows x 11 columns]

# %%
df1.drop([645,882,925],inplace=True)
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_2204\1369527837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([645,882,925],inplace=True)
