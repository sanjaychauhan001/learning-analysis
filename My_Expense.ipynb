# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\sanja\\OneDrive\\Pictures\\excel\\myExpenses1.csv")
df
# Out:
#           Date             Item  Amount Category   Time        day
# 0     1/3/2023             chai     7.0    alone   7:00  Wednesday
# 1     1/3/2023             chai    20.0   friend  10:00  Wednesday
# 2     1/3/2023            juice    15.0   friend  13:00  Wednesday
# 3     1/3/2023          rikshow    12.0    alone  14:00  Wednesday
# 4     1/3/2023           coffee    12.0    alone  15:00  Wednesday
# ..         ...              ...     ...      ...    ...        ...
# 142  31/3/2023  chai with snaks    15.0    alone   9:00     Friday
# 143  31/3/2023         coldrink    20.0   friend  15:00     Friday
# 144  31/3/2023  chai with snaks    25.0    alone  17:00     Friday
# 145        NaN              NaN     NaN      NaN    NaN        NaN
# 146        NaN              NaN     NaN      NaN    NaN        NaN
#
# [147 rows x 6 columns]

# %%
df.describe()
# Out:
#            Amount
# count  145.000000
# mean    31.786207
# std     56.389541
# min      5.000000
# 25%     12.000000
# 50%     17.000000
# 75%     30.000000
# max    500.000000

# %%
df.dropna()
# Out:
#           Date             Item  Amount Category   Time        day
# 0     1/3/2023             chai     7.0    alone   7:00  Wednesday
# 1     1/3/2023             chai    20.0   friend  10:00  Wednesday
# 2     1/3/2023            juice    15.0   friend  13:00  Wednesday
# 3     1/3/2023          rikshow    12.0    alone  14:00  Wednesday
# 4     1/3/2023           coffee    12.0    alone  15:00  Wednesday
# ..         ...              ...     ...      ...    ...        ...
# 140  30/3/2023  chai with snaks    15.0    alone  17:30   Thursday
# 141  30/3/2023           others    20.0    alone  19:00   Thursday
# 142  31/3/2023  chai with snaks    15.0    alone   9:00     Friday
# 143  31/3/2023         coldrink    20.0   friend  15:00     Friday
# 144  31/3/2023  chai with snaks    25.0    alone  17:00     Friday
#
# [144 rows x 6 columns]

# %%
df.Amount.sum()
# Out:
# 4599.0

# %%
df.Item.unique()
# Out:
# array(['chai', 'juice', 'rikshow', 'coffee', 'chai with snaks',
#        'coldrink', 'others', 'chiness bhel', 'idli', 'choclate',
#        'ice cream', 'shoe', 'faluda', 'chass', 'pizza', 'biryani', 'wifi',
#        'chicken', 'recharge', 'petrol', 'samosa', 'freanky', 'maggi', nan],
#       dtype=object)

# %%
df1 = df.groupby("Item").sum().sort_values(by="Amount",ascending=False).head(10)
df1 = df1.reset_index()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_2108\3822449291.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby("Item").sum().sort_values(by="Amount",ascending=False).head(10)

# %%
sns.barplot(x=df1.Item, y=df1.Amount,data=df1)
# Out:
# <Axes: xlabel='Item', ylabel='Amount'>

# %%
df2 = df.groupby("Date").sum().sort_values(by="Amount",ascending=False).head(5)
df2 = df2.reset_index()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_2108\421728946.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby("Date").sum().sort_values(by="Amount",ascending=False).head(5)

# %%
sns.barplot(x=df2.Date, y=df2.Amount, data=df2)
# Out:
# <Axes: xlabel='Date', ylabel='Amount'>

# %%
df3 = df.groupby("day").sum().sort_values(by="Amount",ascending=False)
df3 = df3.reset_index()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_2108\2733221275.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby("day").sum().sort_values(by="Amount",ascending=False)

# %%
colors = sns.color_palette('bright')[0:5]
plt.pie(data=df3,labels=df3.day,colors=colors,x="Amount",autopct='%.0f%%')
plt.show()

# %%
df = df.dropna()
df
# Out:
#           Date             Item  Amount Category   Time        day
# 0     1/3/2023             chai     7.0    alone   7:00  Wednesday
# 1     1/3/2023             chai    20.0   friend  10:00  Wednesday
# 2     1/3/2023            juice    15.0   friend  13:00  Wednesday
# 3     1/3/2023          rikshow    12.0    alone  14:00  Wednesday
# 4     1/3/2023           coffee    12.0    alone  15:00  Wednesday
# ..         ...              ...     ...      ...    ...        ...
# 140  30/3/2023  chai with snaks    15.0    alone  17:30   Thursday
# 141  30/3/2023           others    20.0    alone  19:00   Thursday
# 142  31/3/2023  chai with snaks    15.0    alone   9:00     Friday
# 143  31/3/2023         coldrink    20.0   friend  15:00     Friday
# 144  31/3/2023  chai with snaks    25.0    alone  17:00     Friday
#
# [144 rows x 6 columns]

# %%
df4 = df.groupby("Category").sum()
df4
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_2108\878000244.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df4 = df.groupby("Category").sum()
#           Amount
# Category
# alone     2710.0
# friend    1889.0

# %%
df.groupby("Time").sum().sort_values(by="Amount",ascending=False)
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_2108\2669738178.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Time").sum().sort_values(by="Amount",ascending=False)
#              Amount
# Time
# 17:30         625.0
# 9:00          545.0
# 12:00         375.0
# 10:30         350.0
# 21:00         310.0
# 18:00         302.0
# 15:00         217.0
# 10:00         210.0
# 13:00         202.0
# 16:00         200.0
# 23:30         200.0
# 17:00         169.0
# 14:00         156.0
# 19:00         144.0
# 11:00          85.0
# 21:30          75.0
# 20:00          74.0
# 7:00           72.0
# 9:30           60.0
# 22:40          50.0
# 10:32          40.0
# 15:30          29.0
# 19:30          20.0
# 17:20          20.0
# 14:10          20.0
# 22:30          15.0
# 14:30          12.0
# ...

# %% [markdown]
# ### CONCLUSION
# 1. total money spent is 4599
# 2. most money spent on chai with snacks followed by biryani
# 3. most money spent on 5/3/23 which is around 630
# 4. 28% of money spent on sunday and only 8% of money spent on friday
# 5. the money spent in alone is 2710 and with friends is 1889
# 6. spent alot money at 5 pm
