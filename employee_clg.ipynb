# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\sanjay\\Downloads\\employees.csv")
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df['Senior Management'].fillna(df['Senior Management'].mode()[0], inplace=True)

# %%
df['Senior Management'].isna().sum()
# Out:
# 0

# %%
df['Team'].fillna(df['Team'].mode()[0],inplace=True)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True  Client Services
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
plt.hist(df['Salary'])
plt.show()

# %%
sns.kdeplot(df['Bonus %'])
plt.show()

# %%
plt.scatter(df['Salary'], df['Bonus %'])

# %% [markdown]
# ## the columns are generated using uniform distribution

# %%
plt.pie(df['Gender'].value_counts().values, labels=df['Gender'].value_counts().index, autopct="%0.1f%%")
plt.show()

# %% [markdown]
# ## 57% employees are female and 42% employess are male

# %%
plt.pie(df['Senior Management'].value_counts().values, labels=df['Senior Management'].value_counts().index, autopct="%0.1f%%")
plt.show()

# %% [markdown]
# ## there are 53 percent employess who are at senior level

# %%
df['Team'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Team'>

# %% [markdown]
# ## highest number of employee are working in client services

# %%
x = np.array([df[df['Gender'] == 'Male']['Salary'].mean(),  df[df['Gender'] == 'Female']['Salary'].mean()])

# %%
x
# Out:
# array([91180.66981132, 90280.515625  ])

# %%
plt.pie(x=x, labels=['Male', 'Female'], autopct='%0.2f')
plt.show()

# %% [markdown]
# ## the distribution of salary in male and female are same

# %%
df.groupby('Team')['Salary'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Team'>

# %% [markdown]
# ## the distribution of salary between teams are almost same
