# %%
import pandas as pd
import numpy as np
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 4.,  5., 12., 14., 22., 19., 15.,  5.,  1.,  3.]),
#  array([-2.37910161, -1.88238178, -1.38566196, -0.88894214, -0.39222231,
#          0.10449751,  0.60121734,  1.09793716,  1.59465698,  2.09137681,
#          2.58809663]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 4.,  3.,  3., 14., 13., 15., 10., 11.,  2.,  5.]),
#  array([-2.59924246, -2.100999  , -1.60275555, -1.10451209, -0.60626864,
#         -0.10802519,  0.39021827,  0.88846172,  1.38670518,  1.88494863,
#          2.38319208]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1, color="indianred", alpha=0.5, bins=20 )
plt.hist(dataset2, alpha=0.5, bins=20)
# Out:
# (array([2., 2., 0., 3., 1., 2., 7., 7., 7., 6., 8., 7., 4., 6., 6., 5., 1.,
#         1., 3., 2.]),
#  array([-2.59924246, -2.35012073, -2.100999  , -1.85187728, -1.60275555,
#         -1.35363382, -1.10451209, -0.85539037, -0.60626864, -0.35714691,
#         -0.10802519,  0.14109654,  0.39021827,  0.63933999,  0.88846172,
#          1.13758345,  1.38670518,  1.6358269 ,  1.88494863,  2.13407036,
#          2.38319208]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,kind="hex")
sns.jointplot(data2)

# %%
data1 = pd.read_clipboard()

# %%
data1
# Out:
#     Type of property  Year of rent  Area (ft.) Rental Price Country  \
# 0          Apartment          2018         743      $2,461      USA
# 1          Apartment          2013         743      $2,461      USA
# 2          Apartment          2019         743      $2,461      USA
# 3          Apartment          2013         743      $2,461      USA
# 4          Apartment          2017         743      $2,461      USA
# ..               ...           ...         ...          ...     ...
# 164        Apartment          2015         743      $2,461      USA
# 165        Apartment          2015         743      $2,461      USA
# 166        Apartment          2015         743      $2,461      USA
# 167        Apartment          2013         743      $2,461      USA
# 168        Apartment          2012         743      $2,461      USA
#
#           State
# 0    California
# 1    California
# 2    California
# 3    California
# 4    California
# ..          ...
# 164  California
# 165  California
# 166  California
# 167  California
# 168  California
#
# [169 rows x 6 columns]

# %%
plt.hist(data1['Rental Price'],bins=20)
# Out:
# (array([115.,   3.,   4.,   2.,   3.,   3.,   2.,   3.,   3.,   2.,   3.,
#           3.,   3.,   2.,   3.,   4.,   2.,   3.,   3.,   3.]),
#  array([ 0. ,  2.7,  5.4,  8.1, 10.8, 13.5, 16.2, 18.9, 21.6, 24.3, 27. ,
#         29.7, 32.4, 35.1, 37.8, 40.5, 43.2, 45.9, 48.6, 51.3, 54. ]),
#  <BarContainer object of 20 artists>)

# %%
data1
# Out:
#     Type of property  Year of rent  Area (ft.) Rental Price Country  \
# 0          Apartment          2018         743      $2,461      USA
# 1          Apartment          2013         743      $2,461      USA
# 2          Apartment          2019         743      $2,461      USA
# 3          Apartment          2013         743      $2,461      USA
# 4          Apartment          2017         743      $2,461      USA
# ..               ...           ...         ...          ...     ...
# 164        Apartment          2015         743      $2,461      USA
# 165        Apartment          2015         743      $2,461      USA
# 166        Apartment          2015         743      $2,461      USA
# 167        Apartment          2013         743      $2,461      USA
# 168        Apartment          2012         743      $2,461      USA
#
#           State
# 0    California
# 1    California
# 2    California
# 3    California
# 4    California
# ..          ...
# 164  California
# 165  California
# 166  California
# 167  California
# 168  California
#
# [169 rows x 6 columns]
