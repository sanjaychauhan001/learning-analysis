# %%
import pandas as pd
import numpy as np

# %%
t1 = pd.Timestamp("29th Nov 2023 6:29:55")
t2 = pd.Timestamp("1st jan 2024 12:00:00")
t2-t1
# Out:
# Timedelta('33 days 05:30:05')

# %%
df = pd.read_csv("C:\\Users\\sanja\Downloads\\GOOGL.csv")
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  50.050049  52.082081  48.028027  50.220219  50.220219  44659096
# 1  2004-08-20  50.555557  54.594597  50.300301  54.209209  54.209209  22834343
# 2  2004-08-23  55.430431  56.796799  54.579578  54.754753  54.754753  18256126
# 3  2004-08-24  55.675674  55.855858  51.836838  52.487488  52.487488  15247337
# 4  2004-08-25  52.532532  54.054054  51.991993  53.053055  53.053055   9188602

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4431 entries, 0 to 4430
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4431 non-null   object
#  1   Open       4431 non-null   float64
#  2   High       4431 non-null   float64
#  3   Low        4431 non-null   float64
#  4   Close      4431 non-null   float64
#  5   Adj Close  4431 non-null   float64
#  6   Volume     4431 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 242.4+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4431 entries, 0 to 4430
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4431 non-null   datetime64[ns]
#  1   Open       4431 non-null   float64
#  2   High       4431 non-null   float64
#  3   Low        4431 non-null   float64
#  4   Close      4431 non-null   float64
#  5   Adj Close  4431 non-null   float64
#  6   Volume     4431 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 242.4 KB

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  50.050049  52.082081  48.028027  50.220219  50.220219  44659096
# 2004-08-20  50.555557  54.594597  50.300301  54.209209  54.209209  22834343
# 2004-08-23  55.430431  56.796799  54.579578  54.754753  54.754753  18256126
# 2004-08-24  55.675674  55.855858  51.836838  52.487488  52.487488  15247337
# 2004-08-25  52.532532  54.054054  51.991993  53.053055  53.053055   9188602

# %%
df.loc['2006-08-10']
# Out:
# Open         1.871271e+02
# High         1.890240e+02
# Low          1.864164e+02
# Close        1.872873e+02
# Adj Close    1.872873e+02
# Volume       8.515276e+06
# Name: 2006-08-10 00:00:00, dtype: float64

# %%
df['month_name'] = df.index.month_name()
df['weekday'] = df.index.day_name()
df['quarter'] = df.index.quarter

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  50.050049  52.082081  48.028027  50.220219  50.220219  44659096
# 2004-08-20  50.555557  54.594597  50.300301  54.209209  54.209209  22834343
# 2004-08-23  55.430431  56.796799  54.579578  54.754753  54.754753  18256126
# 2004-08-24  55.675674  55.855858  51.836838  52.487488  52.487488  15247337
# 2004-08-25  52.532532  54.054054  51.991993  53.053055  53.053055   9188602
#
#            month_name    weekday  quarter
# Date
# 2004-08-19     August   Thursday        3
# 2004-08-20     August     Friday        3
# 2004-08-23     August     Monday        3
# 2004-08-24     August    Tuesday        3
# 2004-08-25     August  Wednesday        3

# %%
pd.date_range(start='2005-01-6',end='2020-01-06',freq=pd.DateOffset(years=1))

df[df.index.isin(pd.date_range(start='2005-01-6',end='2020-01-06',freq=pd.DateOffset(years=1)))]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2005-01-06    97.637634    98.048050    93.953957    94.369370    94.369370
# 2006-01-06   228.663666   235.485489   226.846848   233.063065   233.063065
# 2009-01-06   166.656662   170.570572   163.358353   167.197205   167.197205
# 2010-01-06   313.243256   313.243256   303.483490   304.434448   304.434448
# 2011-01-06   305.645660   309.524536   305.330322   307.057068   307.057068
# 2012-01-06   329.904907   330.330322   325.220215   325.335327   325.335327
# 2014-01-06   557.062073   559.989990   553.773804   559.219238   559.219238
# 2015-01-06   520.500000   521.210022   505.549988   506.640015   506.640015
# 2016-01-06   750.369995   765.729980   748.000000   759.330017   759.330017
# 2017-01-06   814.989990   828.960022   811.500000   825.210022   825.210022
# 2020-01-06  1351.630005  1398.319946  1351.000000  1397.810059  1397.810059
#
# ...

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
subset_df = df[['Open','Close','High','Low']]
subset_df.plot(subplots=True,layout=(2,2),figsize=(20,15),
               sharex=False,legend=False,fontsize=20,
               sharey=False,linewidth=0.7,
               title=['Open','Close','High','Low'])
# Out:
# array([[<Axes: title={'center': 'Open'}, xlabel='Date'>,
#         <Axes: title={'center': 'Close'}, xlabel='Date'>],
#        [<Axes: title={'center': 'High'}, xlabel='Date'>,
#         <Axes: title={'center': 'Low'}, xlabel='Date'>]], dtype=object)

# %%
df.loc['2020']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
