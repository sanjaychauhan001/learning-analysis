# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\sanja\\Downloads\\details.csv")
df.head(15)
# Out:
#     match_id match_name current_innings  innings_id  over  ball  runs  \
# 0    1298179  ENG v PAK             PAK           1     1     1     0
# 1    1298179  ENG v PAK             PAK           1     1     1     1
# 2    1298179  ENG v PAK             PAK           1     1     1     1
# 3    1298179  ENG v PAK             PAK           1     1     2     2
# 4    1298179  ENG v PAK             PAK           1     1     3     0
# 5    1298179  ENG v PAK             PAK           1     1     4     1
# 6    1298179  ENG v PAK             PAK           1     1     5     0
# 7    1298179  ENG v PAK             PAK           1     1     6     3
# 8    1298179  ENG v PAK             PAK           1     2     1     0
# 9    1298179  ENG v PAK             PAK           1     2     1     1
# 10   1298179  ENG v PAK             PAK           1     2     2     0
# 11   1298179  ENG v PAK             PAK           1     2     3     1
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'match_name', 'current_innings', 'innings_id', 'over',
#        'ball', 'runs', 'isBoundary', 'isWide', 'isNoball', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_name', 'bowler1_overs',
#        'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts', 'batsman2_name',
#        'batsman2_runs', 'batsman2_balls'],
#       dtype='object')

# %%
df[['batsman1_name','batsman1_runs']]
# Out:
#             batsman1_name  batsman1_runs
# 0         Mohammad Rizwan              0
# 1         Mohammad Rizwan              0
# 2         Mohammad Rizwan              0
# 3         Mohammad Rizwan              2
# 4         Mohammad Rizwan              2
# ...                   ...            ...
# 9809   Maheesh Theekshana             11
# 9810  Dushmantha Chameera              8
# 9811  Dushmantha Chameera              8
# 9812  Dushmantha Chameera              8
# 9813  Dushmantha Chameera              8
#
# [9814 rows x 2 columns]

# %%
df.groupby("batsman1_name")['batsman1_runs'].sum().sort_values(ascending=False)
# Out:
# batsman1_name
# Virat Kohli             5615
# Pathum Nissanka         5094
# Max O'Dowd              4491
# Glenn Phillips          4408
# Jos Buttler             4326
#                         ...
# Timm van der Gugten        0
# Hasan Mahmud               0
# Mohammed Shami             0
# Fazalhaq Farooqi           0
# Danushka Gunathilaka       0
# Name: batsman1_runs, Length: 197, dtype: int64
